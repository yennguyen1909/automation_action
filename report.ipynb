# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("BCPT NVBC (1).csv")

# %%
data1 = pd.read_csv("BCPT NVBC (1).csv")
data2 = pd.read_csv("BCPT NVBC (2).csv")
data3 = pd.read_csv("BCPT NVBC (3).csv")

# %%
data = pd.concat([data1, data2, data3])

# %%
data
# Out:
#        username      id   pkg_order                         action  \
# 0      huyennt6   79830  1038409974                     PickupBill
# 1      huyennt6   79830  1038409974  confirmTmpPickedPackageStatus
# 2      huyennt6   79830  1038409974                     PickupBill
# 3      huyennt6   79830  1038409974        updateDelayPickingByCod
# 4      huyennt6   79830  1038409974        updateDelayPickingByCod
# ...         ...     ...         ...                            ...
# 94475  binhlv58  766133  1857720329               assignCodPicking
# 94476  binhlv58  766133  1274709766               assignCodPicking
# 94477  binhlv58  766133  1274709766               assignCodPicking
# 94478  binhlv58  766133  1274709766               assignCodPicking
# 94479  binhlv58  766133  1274709766               assignCodPicking
#
#                                                     desc       created_action  \
# 0      Hóa đơn nhập hàng vào kho <b>BLH2139971338.T66...  2025-04-11 10:34:14
# ...

# %%
data.isnull().sum()
# Out:
# username             0
# id                   0
# pkg_order            0
# action               0
# desc              9192
# created_action       0
# created_pk           0
# dtype: int64

# %%
df = data.copy()

# %%
x = df[df.pop('desc').isna()]

# %%
x["action"].value_counts()
# Out:
# action
# changePackageStatus    9192
# Name: count, dtype: int64

# %%
data
# Out:
#        username      id   pkg_order                         action  \
# 0      huyennt6   79830  1038409974                     PickupBill
# 1      huyennt6   79830  1038409974  confirmTmpPickedPackageStatus
# 2      huyennt6   79830  1038409974                     PickupBill
# 3      huyennt6   79830  1038409974        updateDelayPickingByCod
# 4      huyennt6   79830  1038409974        updateDelayPickingByCod
# ...         ...     ...         ...                            ...
# 94475  binhlv58  766133  1857720329               assignCodPicking
# 94476  binhlv58  766133  1274709766               assignCodPicking
# 94477  binhlv58  766133  1274709766               assignCodPicking
# 94478  binhlv58  766133  1274709766               assignCodPicking
# 94479  binhlv58  766133  1274709766               assignCodPicking
#
#                                                     desc       created_action  \
# 0      Hóa đơn nhập hàng vào kho <b>BLH2139971338.T66...  2025-04-11 10:34:14
# ...

# %%
data['desc'].fillna("Thay đổi trạng thái điều phối đơn hàng", inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13700\3433567405.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['desc'].fillna("Thay đổi trạng thái điều phối đơn hàng", inplace=True)

# %%
duplicates = data[data.duplicated(keep=False)]
duplicates
# Out:
#        username      id   pkg_order                     action  \
# 40822  huyennt6   79830  1464056762         privateNotePackage
# 40823  huyennt6   79830  1464056762         privateNotePackage
# 54415  huyennt6   79830  1655338793              printfPackage
# 54417  huyennt6   79830  1655338793              printfPackage
# 3257    quanvc5  778000  1705249681         privateNotePackage
# ...         ...     ...         ...                        ...
# 90413  binhlv58  766133  1919085359  smartScaleScanningPackage
# 90978  binhlv58  766133  1530439323       verifySessionPackage
# 90979  binhlv58  766133  1530439323       verifySessionPackage
# 92949  binhlv58  766133  1143015341  smartScaleScanningPackage
# 92951  binhlv58  766133  1143015341  smartScaleScanningPackage
#
#                                                     desc       created_action  \
# 40822  Phiên kiểm VS2625596: Xác nhận có hàng tại kho...  2025-04-05 09:16:13
# ...

# %%
data = data.drop_duplicates(keep='first')

# %%
data = data.sort_values(["username", "pkg_order", "created_action"], ascending = [True,True, True])

# %%
data
# Out:
#        username      id   pkg_order                 action  \
# 25963  binhlv58  766133  1000121785       assignCodPicking
# 25976  binhlv58  766133  1000121785       assignCodPicking
# 25973  binhlv58  766133  1000121785       assignCodPicking
# 25970  binhlv58  766133  1000121785     ArrivePickingPoint
# 25969  binhlv58  766133  1000121785     ArrivePickingPoint
# ...         ...     ...         ...                    ...
# 27190   quanvc5  778000  4010360305       updateDeliverCod
# 27191   quanvc5  778000  4010360305            editPackage
# 27192   quanvc5  778000  4010360305  distributorCfmDeliver
# 78182   quanvc5  778000  4010360489     privateNotePackage
# 5386    quanvc5  778000  4010362086   verifySessionPackage
#
#                                                     desc       created_action  \
# 25963             Xác nhận cod LÊ TRỌNG NGỌC đi lấy hàng  2025-04-09 14:37:52
# 25976             Xác nhận cod NGUYỄN ANH TÚ đi lấy hàng  2025-04-09 14:38:51
# ...

# %%
data = data.reset_index(drop=True)

# %%
#data.to_csv("dataset.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286867 entries, 0 to 286866
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   username        286867 non-null  object
#  1   id              286867 non-null  int64
#  2   pkg_order       286867 non-null  int64
#  3   action          286867 non-null  object
#  4   desc            286867 non-null  object
#  5   created_action  286867 non-null  object
#  6   created_pk      286867 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 15.3+ MB

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("dataset.csv")

# %%
data["created_action"]= pd.to_datetime(data["created_action"])
data["created_pk"]= pd.to_datetime(data["created_pk"])

# %%
data.drop(columns=["Unnamed: 0"], inplace=True)

# %% [markdown]
# Lọc ra từng đơn hàng, xem là mỗi đơn hàng sẽ có các action gì

# %%
orders_actions = data.groupby("pkg_order")["action"].unique().reset_index()

# %%
orders_actions
# Out:
#         pkg_order                                             action
# 0      1000102468  [assignCodPicking, putPackages2Bag, assignBagW...
# 1      1000121785  [assignCodPicking, ArrivePickingPoint, updateT...
# 2      1000188082  [updateDelayPickingByCod, confirmTmpPickedPack...
# 3      1000201730  [assignCodPicking, importStationByDistributer,...
# 4      1000228472  [changePackageStatus, confirmTmpPickedPackageS...
# ...           ...                                                ...
# 53903  4010360305  [verifySessionPackage, distributorCfmDeliver, ...
# 53904  4010360489                               [privateNotePackage]
# 53905  4010361902         [verifySessionBags, distributorCfmDeliver]
# 53906  4010362086                             [verifySessionPackage]
# 53907  4010362352  [verifySessionBags, updateDeliverWorkshiftByCo...
#
# [53908 rows x 2 columns]

# %%
print(type(orders_actions['action'].iloc[0]))
# Out:
# <class 'numpy.ndarray'>

# %%
orders_actions['length'] = orders_actions['action'].apply(lambda x: len(x))

# %%
orders_actions
# Out:
#         pkg_order                                             action  length
# 0      1000102468  [assignCodPicking, putPackages2Bag, assignBagW...       9
# 1      1000121785  [assignCodPicking, ArrivePickingPoint, updateT...       8
# 2      1000188082  [updateDelayPickingByCod, confirmTmpPickedPack...       6
# 3      1000201730  [assignCodPicking, importStationByDistributer,...       3
# 4      1000228472  [changePackageStatus, confirmTmpPickedPackageS...       3
# ...           ...                                                ...     ...
# 53903  4010360305  [verifySessionPackage, distributorCfmDeliver, ...       4
# 53904  4010360489                               [privateNotePackage]       1
# 53905  4010361902         [verifySessionBags, distributorCfmDeliver]       2
# 53906  4010362086                             [verifySessionPackage]       1
# 53907  4010362352  [verifySessionBags, updateDeliverWorkshiftByCo...       3
#
# [53908 rows x 3 columns]

# %%
orders_actions = orders_actions[orders_actions["length"] == 1]

# %%
a = orders_actions["action"].value_counts()

# %%
unique_actions_per_order = data.groupby("pkg_order")["action"].nunique().reset_index(name="num_unique_actions")

# %%
unique_actions_per_order
# Out:
#         pkg_order  num_unique_actions
# 0      1000102468                   9
# 1      1000121785                   8
# 2      1000188082                   6
# 3      1000201730                   3
# 4      1000228472                   3
# ...           ...                 ...
# 53903  4010360305                   4
# 53904  4010360489                   1
# 53905  4010361902                   2
# 53906  4010362086                   1
# 53907  4010362352                   3
#
# [53908 rows x 2 columns]

# %%
data
# Out:
#         username      id   pkg_order                 action  \
# 0       binhlv58  766133  1000121785       assignCodPicking
# 1       binhlv58  766133  1000121785       assignCodPicking
# 2       binhlv58  766133  1000121785       assignCodPicking
# 3       binhlv58  766133  1000121785     ArrivePickingPoint
# 4       binhlv58  766133  1000121785     ArrivePickingPoint
# ...          ...     ...         ...                    ...
# 286862   quanvc5  778000  4010360305       updateDeliverCod
# 286863   quanvc5  778000  4010360305            editPackage
# 286864   quanvc5  778000  4010360305  distributorCfmDeliver
# 286865   quanvc5  778000  4010360489     privateNotePackage
# 286866   quanvc5  778000  4010362086   verifySessionPackage
#
#                                                      desc      created_action  \
# 0                  Xác nhận cod LÊ TRỌNG NGỌC đi lấy hàng 2025-04-09 14:37:52
# 1                  Xác nhận cod NGUYỄN ANH TÚ đi lấy hàng 2025-04-09 14:38:51
# ...

# %%
df = data.copy()

# %%
df = df.sort_values(by = ["pkg_order", "created_action"])

# %%
df
# Out:
#         username      id   pkg_order                       action  \
# 191784   quanvc5  778000  1000102468             assignCodPicking
# 191785   quanvc5  778000  1000102468             assignCodPicking
# 191786   quanvc5  778000  1000102468             assignCodPicking
# 191787   quanvc5  778000  1000102468              putPackages2Bag
# 191788   quanvc5  778000  1000102468     assignBagWithIdentifyBag
# ...          ...     ...         ...                          ...
# 191780  huyennt6   79830  4010361902        distributorCfmDeliver
# 286866   quanvc5  778000  4010362086         verifySessionPackage
# 191781  huyennt6   79830  4010362352            verifySessionBags
# 191782  huyennt6   79830  4010362352  updateDeliverWorkshiftByCod
# 191783  huyennt6   79830  4010362352        distributorCfmDeliver
#
#                                                      desc      created_action  \
# 191784           Xác nhận cod NGUYỄN VĂN XUÂN đi lấy hàng 2025-04-09 08:00:22
# ...

# %%
df["next_action"] = df["action"].shift(-1)
df["next_created"] = df["created_action"].shift(-1)
df["next_pkg_order"] = df["pkg_order"].shift(-1)

# %%
df.head()
# Out:
#        username      id   pkg_order                    action  \
# 191784  quanvc5  778000  1000102468          assignCodPicking
# 191785  quanvc5  778000  1000102468          assignCodPicking
# 191786  quanvc5  778000  1000102468          assignCodPicking
# 191787  quanvc5  778000  1000102468           putPackages2Bag
# 191788  quanvc5  778000  1000102468  assignBagWithIdentifyBag
#
#                                                      desc      created_action  \
# 191784           Xác nhận cod NGUYỄN VĂN XUÂN đi lấy hàng 2025-04-09 08:00:22
# 191785         Xác nhận cod NGUYỄN TRUNG HIẾU đi lấy hàng 2025-04-09 08:15:47
# 191786           Xác nhận cod NGUYỄN VĂN XUÂN đi lấy hàng 2025-04-09 08:58:22
# 191787                Đơn hàng được cho vào túi 721518408 2025-04-09 15:57:06
# 191788  Đơn hàng được cho vào túi 721518408, mã định d... 2025-04-09 15:57:18
#
#                 created_pk                    next_action        next_created  \
# ...

# %% [markdown]
# Tính số lần lặp lại của từng action trong mỗi đơn hàng

# %%
action_changed = (df["action"] != df["action"].shift(1)) | (df["pkg_order"] != df["pkg_order"].shift(1))

# %%
action_changed
# Out:
# 191784     True
# 191785    False
# 191786    False
# 191787     True
# 191788     True
#           ...
# 191780     True
# 286866     True
# 191781     True
# 191782     True
# 191783     True
# Length: 286867, dtype: bool

# %%
group_id = action_changed.cumsum()

# %%
df["repeat_action_count"] = df.groupby(group_id).cumcount() + 1

# %%
df.head()
# Out:
#        username      id   pkg_order                    action  \
# 191784  quanvc5  778000  1000102468          assignCodPicking
# 191785  quanvc5  778000  1000102468          assignCodPicking
# 191786  quanvc5  778000  1000102468          assignCodPicking
# 191787  quanvc5  778000  1000102468           putPackages2Bag
# 191788  quanvc5  778000  1000102468  assignBagWithIdentifyBag
#
#                                                      desc      created_action  \
# 191784           Xác nhận cod NGUYỄN VĂN XUÂN đi lấy hàng 2025-04-09 08:00:22
# 191785         Xác nhận cod NGUYỄN TRUNG HIẾU đi lấy hàng 2025-04-09 08:15:47
# 191786           Xác nhận cod NGUYỄN VĂN XUÂN đi lấy hàng 2025-04-09 08:58:22
# 191787                Đơn hàng được cho vào túi 721518408 2025-04-09 15:57:06
# 191788  Đơn hàng được cho vào túi 721518408, mã định d... 2025-04-09 15:57:18
#
#                 created_pk                    next_action        next_created  \
# ...

# %%
repeated_actions = df[df["repeat_action_count"] > 1]

# %%
repeated_actions
# Out:
#         username      id   pkg_order              action  \
# 191785   quanvc5  778000  1000102468    assignCodPicking
# 191786   quanvc5  778000  1000102468    assignCodPicking
# 1       binhlv58  766133  1000121785    assignCodPicking
# 2       binhlv58  766133  1000121785    assignCodPicking
# 4       binhlv58  766133  1000121785  ArrivePickingPoint
# ...          ...     ...         ...                 ...
# 94331   binhlv58  766133  3319973309    assignCodPicking
# 94332   binhlv58  766133  3319973309    assignCodPicking
# 191772  huyennt6   79830  4010359575  privateNotePackage
# 191773  huyennt6   79830  4010359575  privateNotePackage
# 191774  huyennt6   79830  4010359575  privateNotePackage
#
#                                                      desc      created_action  \
# 191785         Xác nhận cod NGUYỄN TRUNG HIẾU đi lấy hàng 2025-04-09 08:15:47
# 191786           Xác nhận cod NGUYỄN VĂN XUÂN đi lấy hàng 2025-04-09 08:58:22
# ...

# %%
max_repeats = df.groupby(["pkg_order", "action"])["repeat_action_count"].max().reset_index()

# %%
max_repeats.rename(columns={"repeat_action_count": "max_repeat_action_count"}, inplace=True)

# %%
max_repeats
# Out:
#          pkg_order                       action  max_repeat_action_count
# 0       1000102468                   PickupBill                        1
# 1       1000102468      PickupCrossProvinceBill                        1
# 2       1000102468           TransferToBothBill                        1
# 3       1000102468     assignBagWithIdentifyBag                        1
# 4       1000102468             assignCodPicking                        3
# ...            ...                          ...                      ...
# 168943  4010361902            verifySessionBags                        1
# 168944  4010362086         verifySessionPackage                        1
# 168945  4010362352        distributorCfmDeliver                        1
# 168946  4010362352  updateDeliverWorkshiftByCod                        1
# 168947  4010362352            verifySessionBags                        1
#
# [168948 rows x 3 columns]

# %%
most_repeats_by_action = max_repeats.groupby("action")["max_repeat_action_count"].max().sort_values(ascending=False)

# %%
max_repeated_actions = max_repeats[max_repeats["max_repeat_action_count"] > 1]

# %%
max_repeated_actions
# Out:
#          pkg_order              action  max_repeat_action_count
# 4       1000102468    assignCodPicking                        3
# 9       1000121785  ArrivePickingPoint                        2
# 11      1000121785    assignCodPicking                        9
# 29      1000235456    assignCodPicking                        3
# 50      1000442609    assignCodPicking                        2
# ...            ...                 ...                      ...
# 168893  3319643209    assignCodPicking                        4
# 168917  3319913705    assignCodPicking                       18
# 168918  3319913709    assignCodPicking                       12
# 168921  3319973309    assignCodPicking                       12
# 168931  4010359575  privateNotePackage                        4
#
# [21891 rows x 3 columns]

# %% [markdown]
# Tần suất và sự phổ biến của action

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
action_counts = df["action"].value_counts()

# %%
action_counts
# Out:
# action
# assignCodPicking                 100795
# PickupBill                        26623
# confirmTmpPickedPackageStatus     26571
# updateDelayPickingByCod           17246
# verifySessionPackage              10355
#                                   ...
# CODUpdatePickMoney                    1
# unScanPackageCreateBagB2C             1
# confirmChangeAddress                  1
# exportBigSizePackages                 1
# TakeAPhotoReturn                      1
# Name: count, Length: 134, dtype: int64

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis')\
    .generate_from_frequencies(action_counts.to_dict())

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Tần suất các Action", fontsize=16)
plt.show()

# %% [markdown]
# Phân tích chuỗi hành động và quy trình thực hiện

# %%
df
# Out:
#         username      id   pkg_order                       action  \
# 191784   quanvc5  778000  1000102468             assignCodPicking
# 191785   quanvc5  778000  1000102468             assignCodPicking
# 191786   quanvc5  778000  1000102468             assignCodPicking
# 191787   quanvc5  778000  1000102468              putPackages2Bag
# 191788   quanvc5  778000  1000102468     assignBagWithIdentifyBag
# ...          ...     ...         ...                          ...
# 191780  huyennt6   79830  4010361902        distributorCfmDeliver
# 286866   quanvc5  778000  4010362086         verifySessionPackage
# 191781  huyennt6   79830  4010362352            verifySessionBags
# 191782  huyennt6   79830  4010362352  updateDeliverWorkshiftByCod
# 191783  huyennt6   79830  4010362352        distributorCfmDeliver
#
#                                                      desc      created_action  \
# 191784           Xác nhận cod NGUYỄN VĂN XUÂN đi lấy hàng 2025-04-09 08:00:22
# ...

# %%
sequences = df.groupby('pkg_order')['action'].apply(lambda x: ' -> '.join(x)).reset_index()

# %%
sequences
# Out:
#         pkg_order                                             action
# 0      1000102468  assignCodPicking -> assignCodPicking -> assign...
# 1      1000121785  assignCodPicking -> assignCodPicking -> assign...
# 2      1000188082  updateDelayPickingByCod -> confirmTmpPickedPac...
# 3      1000201730  assignCodPicking -> importStationByDistributer...
# 4      1000228472  changePackageStatus -> confirmTmpPickedPackage...
# ...           ...                                                ...
# 53903  4010360305  verifySessionPackage -> distributorCfmDeliver ...
# 53904  4010360489                                 privateNotePackage
# 53905  4010361902         verifySessionBags -> distributorCfmDeliver
# 53906  4010362086                               verifySessionPackage
# 53907  4010362352  verifySessionBags -> updateDeliverWorkshiftByC...
#
# [53908 rows x 2 columns]

# %%
sequence_counts = sequences['action'].value_counts().reset_index()

# %%
sequence_counts.columns = ['sequence', 'count']

# %%
sequence_counts
# Out:
#                                                sequence  count
# 0                                      assignCodPicking  10035
# 1     assignCodPicking -> assignCodPicking -> assign...   3158
# 2                  assignCodPicking -> assignCodPicking   3069
# 3     assignCodPicking -> assignCodPicking -> assign...   2056
# 4     assignCodPicking -> assignCodPicking -> assign...   1311
# ...                                                 ...    ...
# 7431  changePackageStatus -> assignCodPicking -> upd...      1
# 7432  changePackageStatus -> assignCodPicking -> Pic...      1
# 7433  assignCodPicking -> assignCodPicking -> assign...      1
# 7434  changePackageStatus -> confirmTmpPickedPackage...      1
# 7435  verifySessionBags -> updateDeliverWorkshiftByC...      1
#
# [7436 rows x 2 columns]

# %%
top_sequences = sequence_counts.head(10)

# %% [markdown]
# Tần suất chuỗi hành động top 10 cao nhất

# %%
top_sequences
# Out:
#                                             sequence  count
# 0                                   assignCodPicking  10035
# 1  assignCodPicking -> assignCodPicking -> assign...   3158
# 2               assignCodPicking -> assignCodPicking   3069
# 3  assignCodPicking -> assignCodPicking -> assign...   2056
# 4  assignCodPicking -> assignCodPicking -> assign...   1311
# 5                               verifySessionPackage    985
# 6  assignCodPicking -> assignCodPicking -> assign...    927
# 7                   cfmTransit -> TransferToBothBill    853
# 8                              distributorCfmDeliver    776
# 9  assignCodPicking -> confirmTmpPickedPackageSta...    598

# %% [markdown]
# Lọc các chuỗi có độ dài từ 3 hành động trở lên

# %%
sequence_counts['length'] = sequence_counts['sequence'].apply(lambda x: len(x.split('->')))

# %%
long_sequences = sequence_counts[sequence_counts['length'] >= 3]

# %%
long_sequences
# Out:
#                                                sequence  count  length
# 1     assignCodPicking -> assignCodPicking -> assign...   3158       3
# 3     assignCodPicking -> assignCodPicking -> assign...   2056       5
# 4     assignCodPicking -> assignCodPicking -> assign...   1311       5
# 6     assignCodPicking -> assignCodPicking -> assign...    927       4
# 9     assignCodPicking -> confirmTmpPickedPackageSta...    598       5
# ...                                                 ...    ...     ...
# 7431  changePackageStatus -> assignCodPicking -> upd...      1      38
# 7432  changePackageStatus -> assignCodPicking -> Pic...      1      34
# 7433  assignCodPicking -> assignCodPicking -> assign...      1      24
# 7434  changePackageStatus -> confirmTmpPickedPackage...      1      21
# 7435  verifySessionBags -> updateDeliverWorkshiftByC...      1       3
#
# [7310 rows x 3 columns]

# %%
top_long_sequences = long_sequences.sort_values(by='count', ascending=False).head(20)
top_long_sequences
# Out:
#                                              sequence  count  length
# 1   assignCodPicking -> assignCodPicking -> assign...   3158       3
# 3   assignCodPicking -> assignCodPicking -> assign...   2056       5
# 4   assignCodPicking -> assignCodPicking -> assign...   1311       5
# 6   assignCodPicking -> assignCodPicking -> assign...    927       4
# 9   assignCodPicking -> confirmTmpPickedPackageSta...    598       5
# 10  assignCodPicking -> confirmTmpPickedPackageSta...    587       7
# 11  assignCodPicking -> updatePickedByCod -> confi...    539       5
# 12  assignCodPicking -> updatePickedByCod -> confi...    507       7
# 16  putPackages2Bag -> smartScaleScanningPackage -...    335       3
# 17  assignCodPicking -> assignCodPicking -> assign...    308       6
# 18  confirmTmpReturnedPackageStatus -> updateRetur...    285       3
# 20  assignCodPicking -> assignCodPicking -> assign...    273       7
# 21  updateReturnedByCod -> confirmTmpReturnedPacka...    271       3
# ...

# %% [markdown]
# Trích các cặp hành động để làm Association Rule Mining (A → B)

# %%
from collections import Counter

# %%
pair_counter = Counter()

for seq in sequences['action']:
    actions = [x.strip() for x in seq.split('->')]
    for i in range(len(actions) - 1):
        pair = (actions[i], actions[i + 1])
        pair_counter[pair] += 1

pair_df = pd.DataFrame(pair_counter.items(), columns=['pair', 'count'])
pair_df[['from_action', 'to_action']] = pd.DataFrame(pair_df['pair'].tolist(), index=pair_df.index)
pair_df = pair_df.drop(columns=['pair']).sort_values(by='count', ascending=False)

print(pair_df.head(10))
# Out:
#     count                    from_action                      to_action
# 0   57280               assignCodPicking               assignCodPicking
# 4    9772  confirmTmpPickedPackageStatus                     PickupBill
# 48   7528  confirmTmpPickedPackageStatus        updateDelayPickingByCod
# 49   7048        updateDelayPickingByCod                     PickupBill
# 16   6584        updateDelayPickingByCod  confirmTmpPickedPackageStatus
# 53   6461                     PickupBill  confirmTmpPickedPackageStatus
# 76   5824           verifySessionPackage           verifySessionPackage
# 8    5749                     cfmTransit             TransferToBothBill
# 44   5271               assignCodPicking  confirmTmpPickedPackageStatus
# 28   4446                     PickupBill        PickupCrossProvinceBill

# %%
pair_df
# Out:
#       count                    from_action                          to_action
# 0     57280               assignCodPicking                   assignCodPicking
# 4      9772  confirmTmpPickedPackageStatus                         PickupBill
# 48     7528  confirmTmpPickedPackageStatus            updateDelayPickingByCod
# 49     7048        updateDelayPickingByCod                         PickupBill
# 16     6584        updateDelayPickingByCod      confirmTmpPickedPackageStatus
# ...     ...                            ...                                ...
# 595       1       assignBagWithIdentifyBag                updateReturnedByCod
# 914       1     changeCustomerFirstAddress  changeTransferStationByChangeCart
# 150       1       assignBagWithIdentifyBag                  verifySessionBags
# 912       1          distributorCfmDeliver                   changeCurStation
# 1147      1             privateNotePackage          saveSealForSpecialPackage
#
# [1148 rows x 3 columns]

# %%
from matplotlib.dates import date2num

# %% [markdown]
# Biểu đồ Sankey

# %%
# !pip install plotly

# %%
from collections import defaultdict
import plotly.graph_objects as go
node_labels = []
label_to_index = {}
links = defaultdict(int)

# %%
top_sequences = [
    ("assignCodPicking", 10035),
    ("assignCodPicking -> assignCodPicking -> assignCodPicking", 3158),
    ("assignCodPicking -> assignCodPicking", 3069),
    ("assignCodPicking -> assignCodPicking -> assignCodPicking -> assignCodPicking -> assignCodPicking", 2056),
    ("assignCodPicking -> assignCodPicking -> assignCodPicking -> cfmTransit -> TransferToBothBill", 1311),
    ("verifySessionPackage", 985),
    ("assignCodPicking -> assignCodPicking -> assignCodPicking -> assignCodPicking", 927),
    ("cfmTransit -> TransferToBothBill", 853),
    ("distributorCfmDeliver", 776),
    ("assignCodPicking -> confirmTmpPickedPackageStatus -> updatePickedByCod -> PickupBill -> PickupCrossProvinceBill", 598)
]

# %%
for seq, count in top_sequences:
    steps = seq.split(" -> ")
    for i in range(len(steps) - 1):
        source, target = steps[i], steps[i + 1]
        links[(source, target)] += count

        for step in (source, target):
            if step not in label_to_index:
                label_to_index[step] = len(node_labels)
                node_labels.append(step)

# %%
node_labels = []
label_to_index = {}
links = defaultdict(int)

# %%
for seq, count in top_sequences:
    steps = seq.split(" -> ")
    for i in range(len(steps) - 1):
        source, target = steps[i], steps[i + 1]
        links[(source, target)] += count

        for step in (source, target):
            if step not in label_to_index:
                label_to_index[step] = len(node_labels)
                node_labels.append(step)

# Chuẩn bị dữ liệu cho Sankey diagram
source_indices = []
target_indices = []
values = []

for (source, target), value in links.items():
    source_indices.append(label_to_index[source])
    target_indices.append(label_to_index[target])
    values.append(value)

# Vẽ biểu đồ Sankey
sankey_fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=node_labels
    ),
    link=dict(
        source=source_indices,
        target=target_indices,
        value=values
    )
)])
sankey_fig.update_layout(title_text="Sankey Diagram với luồng chuỗi hành động phổ biến", font_size=10)

# %%
sequences
# Out:
#         pkg_order                                             action
# 0      1000102468  assignCodPicking -> assignCodPicking -> assign...
# 1      1000121785  assignCodPicking -> assignCodPicking -> assign...
# 2      1000188082  updateDelayPickingByCod -> confirmTmpPickedPac...
# 3      1000201730  assignCodPicking -> importStationByDistributer...
# 4      1000228472  changePackageStatus -> confirmTmpPickedPackage...
# ...           ...                                                ...
# 53903  4010360305  verifySessionPackage -> distributorCfmDeliver ...
# 53904  4010360489                                 privateNotePackage
# 53905  4010361902         verifySessionBags -> distributorCfmDeliver
# 53906  4010362086                               verifySessionPackage
# 53907  4010362352  verifySessionBags -> updateDeliverWorkshiftByC...
#
# [53908 rows x 2 columns]

# %%
df['hour'] = df['created_action'].dt.hour
df['weekday'] = df['created_action'].dt.dayofweek  # 0: Monday, 6: Sunday
df['date'] = df['created_action'].dt.date

# %%
import seaborn as sns

# %%
sequence = df.groupby('pkg_order')['action'].apply(list).tolist()

# %%
sequences
# Out:
#         pkg_order                                             action
# 0      1000102468  assignCodPicking -> assignCodPicking -> assign...
# 1      1000121785  assignCodPicking -> assignCodPicking -> assign...
# 2      1000188082  updateDelayPickingByCod -> confirmTmpPickedPac...
# 3      1000201730  assignCodPicking -> importStationByDistributer...
# 4      1000228472  changePackageStatus -> confirmTmpPickedPackage...
# ...           ...                                                ...
# 53903  4010360305  verifySessionPackage -> distributorCfmDeliver ...
# 53904  4010360489                                 privateNotePackage
# 53905  4010361902         verifySessionBags -> distributorCfmDeliver
# 53906  4010362086                               verifySessionPackage
# 53907  4010362352  verifySessionBags -> updateDeliverWorkshiftByC...
#
# [53908 rows x 2 columns]

# %%
username_df = df.groupby('pkg_order')['username'].first().reset_index()

# %%
sequences_username = sequences.merge (username_df, on = "pkg_order", how = "left")

# %%
sequences_username
# Out:
#         pkg_order                                             action  username
# 0      1000102468  assignCodPicking -> assignCodPicking -> assign...   quanvc5
# 1      1000121785  assignCodPicking -> assignCodPicking -> assign...  binhlv58
# 2      1000188082  updateDelayPickingByCod -> confirmTmpPickedPac...  huyennt6
# 3      1000201730  assignCodPicking -> importStationByDistributer...   quanvc5
# 4      1000228472  changePackageStatus -> confirmTmpPickedPackage...  huyennt6
# ...           ...                                                ...       ...
# 53903  4010360305  verifySessionPackage -> distributorCfmDeliver ...   quanvc5
# 53904  4010360489                                 privateNotePackage   quanvc5
# 53905  4010361902         verifySessionBags -> distributorCfmDeliver  huyennt6
# 53906  4010362086                               verifySessionPackage   quanvc5
# 53907  4010362352  verifySessionBags -> updateDeliverWorkshiftByC...  huyennt6
#
# ...

# %% [markdown]
# Phân tích chuỗi hành động với từng Nhân viên bưu cục
# 1. quancv1

# %%
sequences_quanvc5 = sequences_username[sequences_username["username"] == "quanvc5"]

# %%
sequences_quanvc5
# Out:
#         pkg_order                                             action username
# 0      1000102468  assignCodPicking -> assignCodPicking -> assign...  quanvc5
# 3      1000201730  assignCodPicking -> importStationByDistributer...  quanvc5
# 5      1000235456  assignCodPicking -> assignCodPicking -> assign...  quanvc5
# 6      1000263560                                   assignCodPicking  quanvc5
# 7      1000281533                                   assignCodPicking  quanvc5
# ...           ...                                                ...      ...
# 53900  4010358554                               verifySessionPackage  quanvc5
# 53901  4010359124                                 privateNotePackage  quanvc5
# 53903  4010360305  verifySessionPackage -> distributorCfmDeliver ...  quanvc5
# 53904  4010360489                                 privateNotePackage  quanvc5
# 53906  4010362086                               verifySessionPackage  quanvc5
#
# [21326 rows x 3 columns]

# %%
sequences_quanvc5['length'] = sequences_quanvc5['action'].apply(lambda x: len(x.split('->')))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13968\4141035902.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sequences_quanvc5
# Out:
#         pkg_order                                             action username  \
# 0      1000102468  assignCodPicking -> assignCodPicking -> assign...  quanvc5
# 3      1000201730  assignCodPicking -> importStationByDistributer...  quanvc5
# 5      1000235456  assignCodPicking -> assignCodPicking -> assign...  quanvc5
# 10     1000362734  putPackages2Bag -> assignBagWithIdentifyBag ->...  quanvc5
# 12     1000402148  putPackages2Bag -> assignBagWithIdentifyBag ->...  quanvc5
# ...           ...                                                ...      ...
# 53855  3318043906  updateDelayDeliveringByCod -> confirmTmpDelive...  quanvc5
# 53865  3318543409  confirmTmpReturnedPackageStatus -> updateRetur...  quanvc5
# 53874  3319113009  feedbackCancelPackage -> PickupBill -> changeP...  quanvc5
# 53889  3319843005  distributorCfmDeliver -> confirmTmpDeliveredPa...  quanvc5
# 53903  4010360305  verifySessionPackage -> distributorCfmDeliver ...  quanvc5
#
#        length
# 0          11
# ...

# %%
top_sequences_quancv1 = sequences_quanvc5["action"].value_counts().head(15)

# %%
top_sequences_quancv1 = top_sequences_quancv1.reset_index()

# %%
top_sequences_quancv1.columns = ['action', 'count']
top_sequences_quancv1['length'] = top_sequences_quancv1['action'].apply(lambda x: len(x.split('->')))

# %%
top_sequences_quancv1
# Out:
#                                                action  count  length
# 0                                    assignCodPicking   4118       1
# 1   assignCodPicking -> assignCodPicking -> assign...   1607       5
# 2   assignCodPicking -> assignCodPicking -> assign...   1463       3
# 3   assignCodPicking -> assignCodPicking -> assign...   1291       5
# 4   assignCodPicking -> confirmTmpPickedPackageSta...    587       7
# 5   assignCodPicking -> confirmTmpPickedPackageSta...    555       5
# 6                               distributorCfmDeliver    540       1
# 7   assignCodPicking -> updatePickedByCod -> confi...    507       7
# 8   assignCodPicking -> updatePickedByCod -> confi...    507       5
# 9                                  privateNotePackage    397       1
# 10                               verifySessionPackage    353       1
# 11        putPackages2Bag -> assignBagWithIdentifyBag    243       2
# 12  distributorCfmReturning -> importStationByDist...    229       2
# ...

# %%
sequences_quanvc5 = sequences_quanvc5[sequences_quanvc5['length'] >= 3]

# %%
sequences_quanvc5["action"].value_counts(). head(30)
# Out:
# action
# assignCodPicking -> assignCodPicking -> assignCodPicking -> assignCodPicking -> assignCodPicking                                                                                                      1607
# assignCodPicking -> assignCodPicking -> assignCodPicking                                                                                                                                              1463
# assignCodPicking -> assignCodPicking -> assignCodPicking -> cfmTransit -> TransferToBothBill                                                                                                          1291
# assignCodPicking -> confirmTmpPickedPackageStatus -> updatePickedByCod -> PickupBill -> PickupCrossProvinceBill -> cfmTransit -> TransferToBothBill                                                    587
# ...

# %%
sequences_quanvc5["action"].value_counts(). head(15).plot(kind='barh', figsize=(8, 9), color='skyblue')
plt.title("Top 15 chuỗi action có từ 3 actions trở lên do NVBC quancv1 thực hiện")
plt.xlabel("Số lần")
plt.ylabel("Action")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13968\1413493888.py:6: UserWarning:
#
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
data_quancv1 = pd.read_csv("BCPT NVBC (2).csv")

# %%
data_quancv1
# Out:
#       username      id   pkg_order                            action  \
# 0      quanvc5  778000  1795616412                  assignCodPicking
# 1      quanvc5  778000  1277203621                  assignCodPicking
# 2      quanvc5  778000  1986694455                  assignCodPicking
# 3      quanvc5  778000  1391304619          TakeAPhotoDeliveryPhotos
# 4      quanvc5  778000  1391304619             ArriveDeliveringPoint
# ...        ...     ...         ...                               ...
# 95084  quanvc5  778000  1035338416  confirmTmpDeliveredPackageStatus
# 95085  quanvc5  778000  1479955820                  assignCodPicking
# 95086  quanvc5  778000  1479955820                  assignCodPicking
# 95087  quanvc5  778000  1479955820                  assignCodPicking
# 95088  quanvc5  778000  1005910591                  assignCodPicking
#
#                                                     desc       created_action  \
# ...

# %%
data_quancv1 ["created_action"] = pd.to_datetime(data_quancv1["created_action"])
data_quancv1 ["created_pk"] = pd.to_datetime(data_quancv1["created_pk"])

# %%
data_quancv1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95089 entries, 0 to 95088
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   username        95089 non-null  object
#  1   id              95089 non-null  int64
#  2   pkg_order       95089 non-null  int64
#  3   action          95089 non-null  object
#  4   desc            95068 non-null  object
#  5   created_action  95089 non-null  datetime64[ns]
#  6   created_pk      95089 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 5.1+ MB

# %%
data_quancv1["action"].value_counts().head(15)
# Out:
# action
# assignCodPicking                   30834
# PickupBill                          6929
# updatePickedByCod                   6924
# confirmTmpPickedPackageStatus       6924
# PickupCrossProvinceBill             6784
# putPackages2Bag                     4279
# assignBagWithIdentifyBag            4171
# cfmTransit                          4044
# TransferToBothBill                  4037
# distributorCfmReturning             3261
# importStationByDistributer          3261
# ReturnBill                          2242
# confirmTmpReturnedPackageStatus     2156
# updateReturnedByCod                 2156
# distributorCfmDeliver               1941
# Name: count, dtype: int64

# %%
data_quancv1["action"].value_counts().head(15).plot(kind='barh', figsize=(8, 5), color='skyblue')
plt.title("Tần suất xuất hiện từng action của NVBC quancv1")
plt.xlabel("Số lần")
plt.ylabel("Action")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. binhlv58

# %%
sequences_binhlv58 = sequences_username[sequences_username["username"] == "binhlv58"]

# %%
sequences_binhlv58['length'] = sequences_binhlv58['action'].apply(lambda x: len(x.split('->')))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13968\1938669233.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
top_sequences_binhlv58 = sequences_binhlv58["action"].value_counts().head(15)

# %%
top_sequences_binhlv58 = top_sequences_binhlv58.reset_index()
top_sequences_binhlv58.columns = ['action', 'count']
top_sequences_binhlv58['length'] = top_sequences_binhlv58['action'].apply(lambda x: len(x.split('->')))

# %%
top_sequences_binhlv58
# Out:
#                                                action  count  length
# 0                                    assignCodPicking   5796       1
# 1                assignCodPicking -> assignCodPicking   3059       2
# 2   assignCodPicking -> assignCodPicking -> assign...   1695       3
# 3   assignCodPicking -> assignCodPicking -> assign...    806       4
# 4                                verifySessionPackage    632       1
# 5   assignCodPicking -> assignCodPicking -> assign...    449       5
# 6            assignCodPicking -> verifySessionPackage    437       2
# 7                    cfmTransit -> TransferToBothBill    376       2
# 8   putPackages2Bag -> smartScaleScanningPackage -...    335       3
# 9   assignCodPicking -> assignCodPicking -> assign...    287       6
# 10  assignCodPicking -> assignCodPicking -> assign...    273       7
# 11       verifySessionPackage -> verifySessionPackage    212       2
# 12  assignCodPicking -> cfmTransit -> TransferToBo...    179       3
# ...

# %%
sequences_binhlv58 = sequences_binhlv58[sequences_binhlv58['length'] >= 3]

# %%
x = sequences_binhlv58["action"].value_counts()

# %%
sequences_binhlv58
# Out:
#         pkg_order                                             action  \
# 1      1000121785  assignCodPicking -> assignCodPicking -> assign...
# 9      1000334032  assignCodPicking -> confirmTmpReturnedPackageS...
# 16     1000530324  putPackages2Bag -> putInBox -> verifySessionPa...
# 17     1000541572  assignCodPicking -> assignCodPicking -> assign...
# 20     1000554632  assignCodPicking -> assignCodPicking -> assign...
# ...           ...                                                ...
# 53885  3319643209  assignCodPicking -> assignCodPicking -> assign...
# 53888  3319833304  confirmTmpPickedPackageStatus -> updateDelayPi...
# 53892  3319913705  assignCodPicking -> assignCodPicking -> assign...
# 53893  3319913709  assignCodPicking -> assignCodPicking -> assign...
# 53895  3319973309  assignCodPicking -> assignCodPicking -> assign...
#
#        username  length
# 1      binhlv58      20
# 9      binhlv58       4
# 16     binhlv58       3
# 17     binhlv58       7
# ...

# %%
sequences_binhlv58["action"].value_counts(). head(20).plot(kind='barh', figsize=(8, 9), color='skyblue')
plt.title("Top 20 chuỗi action có từ 3 actions trở lên do NVBC binhlv58 thực hiện")
plt.xlabel("Số lần")
plt.ylabel("Action")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13968\3569567698.py:6: UserWarning:
#
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
data_binhlv58 = pd.read_csv("BCPT NVBC (3).csv")

# %%
data_binhlv58 ["created_action"] = pd.to_datetime(data_binhlv58["created_action"])
data_binhlv58 ["created_pk"] = pd.to_datetime(data_binhlv58["created_pk"])

# %%
data_binhlv58["action"].value_counts().head(20)
# Out:
# action
# assignCodPicking                   53167
# verifySessionPackage                9637
# PickupBill                          2959
# confirmTmpPickedPackageStatus       2914
# smartScaleScanningPackage           2388
# ReturnBill                          2050
# confirmTmpReturnedPackageStatus     1988
# updateReturnedByCod                 1944
# putPackages2Bag                     1828
# updatePickedByCod                   1670
# putInBox                            1565
# PickupCrossProvinceBill             1371
# updateDelayPickingByCod             1205
# distributorCfmReturning             1191
# TransferToBothBill                  1073
# cfmTransit                           755
# importStationByDistributer           700
# ArrivePickingPoint                   502
# takeReturningPackages                491
# ScanPackageToBag                     453
# Name: count, dtype: int64

# %%
data_binhlv58["action"].value_counts().head(20).plot(kind='barh', figsize=(8, 5), color='skyblue')
plt.title("Tần suất xuất hiện từng action của NVBC binhlv58")
plt.xlabel("Số lần")
plt.ylabel("Action")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3.

# %%
data_huyennt6 = pd.read_csv("BCPT NVBC (1).csv")

# %%
data_huyennt6 ["created_action"] = pd.to_datetime(data_huyennt6["created_action"])
data_huyennt6 ["created_pk"] = pd.to_datetime(data_huyennt6["created_pk"])

# %%
z = data_huyennt6["action"].value_counts().head(20)

# %%
data_huyennt6["action"].value_counts().head(20).plot(kind='barh', figsize=(8, 5), color='skyblue')
plt.title("Tần suất xuất hiện từng action của NVBC data_huyennt6")
plt.xlabel("Số lần")
plt.ylabel("Action")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
sequences_huyennt6 = sequences_username[sequences_username["username"] == "huyennt6"]

# %%
sequences_huyennt6['length'] = sequences_huyennt6['action'].apply(lambda x: len(x.split('->')))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13968\90851501.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sequences_huyennt6["action"].value_counts().head(15)
# Out:
# action
# cfmTransit -> TransferToBothBill                                                                          397
# verifySessionBags -> distributorCfmDeliver                                                                363
# changePackageStatus                                                                                       238
# distributorCfmDeliver                                                                                     236
# verifySessionBags                                                                                         209
# changePackageStatus -> changeCodForPackagesInCart                                                         138
# changeCodForPackagesInCart -> changePackageStatus                                                         130
# assignCodPicking                                                                                          121
# ...

# %%
top_sequences_huyennt6 = sequences_huyennt6["action"].value_counts()

# %%
top_sequences_huyennt6 = top_sequences_huyennt6.reset_index()

# %%
top_sequences_huyennt6.columns = ['action', 'count']
top_sequences_huyennt6['length'] = top_sequences_huyennt6['action'].apply(lambda x: len(x.split('->')))

# %%
top_sequences_huyennt6
# Out:
#                                                  action  count  length
# 0                      cfmTransit -> TransferToBothBill    397       2
# 1            verifySessionBags -> distributorCfmDeliver    363       2
# 2                                   changePackageStatus    238       1
# 3                                 distributorCfmDeliver    236       1
# 4                                     verifySessionBags    209       1
# ...                                                 ...    ...     ...
# 3488  assignCodPicking -> assignCodPicking -> Pickup...      1      13
# 3489  PickupBill -> updateDelayPickingByCod -> confi...      1      47
# 3490  changePackageStatus -> assignCodPicking -> con...      1      27
# 3491  assignCodPicking -> putPackages2Bag -> assignB...      1       5
# 3492  verifySessionBags -> updateDeliverWorkshiftByC...      1       3
#
# [3493 rows x 3 columns]

# %%
sequences_huyennt6 = sequences_huyennt6[sequences_huyennt6['length'] >= 3]

# %%
y = sequences_huyennt6["action"].value_counts().head(20)

# %%
sequences_huyennt6["action"].value_counts(). head(20).plot(kind='barh', figsize=(8, 9), color='skyblue')
plt.title("Top 20 chuỗi action có từ 3 actions trở lên do NVBC huyennt6 thực hiện")
plt.xlabel("Số lần")
plt.ylabel("Action")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13968\1318198465.py:6: UserWarning:
#
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
data_huyennt6
# Out:
#        username     id   pkg_order                         action  \
# 0      huyennt6  79830  1038409974                     PickupBill
# 1      huyennt6  79830  1038409974  confirmTmpPickedPackageStatus
# 2      huyennt6  79830  1038409974                     PickupBill
# 3      huyennt6  79830  1038409974        updateDelayPickingByCod
# 4      huyennt6  79830  1038409974        updateDelayPickingByCod
# ...         ...    ...         ...                            ...
# 97447  huyennt6  79830  1365409147                  printfPackage
# 97448  huyennt6  79830  1365409147       assignBagWithIdentifyBag
# 97449  huyennt6  79830  1932182720                     PickupBill
# 97450  huyennt6  79830  1932182720            changePackageStatus
# 97451  huyennt6  79830  1932182720  confirmTmpPickedPackageStatus
#
#                                                     desc      created_action  \
# 0      Hóa đơn nhập hàng vào kho <b>BLH2139971338.T66... 2025-04-11 10:34:14
# ...

# %%
data_huyennt6_delay = data_huyennt6[data_huyennt6["action"] == "updateDelayPickingByCod"]

# %%
data_huyennt6_delay["desc"].value_counts()
# Out:
# desc
# Cập nhật delay lấy hàng bởi COD    16041
# Name: count, dtype: int64
